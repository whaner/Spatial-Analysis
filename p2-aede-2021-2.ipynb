# %% [markdown]
# # Análise exploratória de dados espaciais - AEDE

# %% [markdown]
# <br>
# Municípios grandes produtores de alguma cultura tendem a estar próximos de municípios também produtores dessa cultura ou de municípios que não o produzem? O objetivo da análise exploratória de dados espaciais (AEDE) é responder a esse tipo de questão. De forma mais geral, a questão é qual a a associação entre o valor de certa variável em um lugar e os valores dessa mesma variável nos lugares vizinhos. Localidades com valores semelhantes de determinada variável tendem a estar próximas? Para isso, ela mede a autocorrelação espacial, por meio do $I$ de Moran.

# %%
# !pip install geopandas==0.8.2
# !pip install --upgrade pyshp
# !pip install shapely  ==1.7.0
# !pip install --upgrade descartes
# !pip install mapclassify==2.3.0 libpysal==4.3.0 splot==1.1.3
# !pip install esda
# !pip install pysal
# Out:
# Requirement already satisfied: geopandas==0.8.2 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (0.8.2)
# Requirement already satisfied: fiona in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from geopandas==0.8.2) (1.8.20)
# Requirement already satisfied: pandas>=0.23.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from geopandas==0.8.2) (1.3.4)
# Requirement already satisfied: shapely in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from geopandas==0.8.2) (1.7.1)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from geopandas==0.8.2) (2.6.1.post1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas==0.8.2) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas==0.8.2) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas==0.8.2) (1.21.2)
# Requirement already satisfied: six>=1.5 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.23.0->geopandas==0.8.2) (1.16.0)
# Requirement already satisfied: cligj>=0.5 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas==0.8.2) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas==0.8.2) (1.1.1)
# Requirement already satisfied: certifi in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas==0.8.2) (2021.10.8)
# Requirement already satisfied: click>=4.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas==0.8.2) (8.0.3)
# Requirement already satisfied: setuptools in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas==0.8.2) (58.0.4)
# Requirement already satisfied: munch in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas==0.8.2) (2.5.0)
# Requirement already satisfied: attrs>=17 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas==0.8.2) (21.2.0)
# Requirement already satisfied: importlib-metadata in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from click>=4.0->fiona->geopandas==0.8.2) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata->click>=4.0->fiona->geopandas==0.8.2) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata->click>=4.0->fiona->geopandas==0.8.2) (3.6.0)
# Requirement already satisfied: pyshp in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (2.2.0)
# zsh:1: =1.7.0 not found
# Requirement already satisfied: descartes in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (1.1.0)
# Requirement already satisfied: matplotlib in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from descartes) (3.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from matplotlib->descartes) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from matplotlib->descartes) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from matplotlib->descartes) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from matplotlib->descartes) (3.0.4)
# Requirement already satisfied: numpy>=1.17 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from matplotlib->descartes) (1.21.2)
# Requirement already satisfied: packaging>=20.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from matplotlib->descartes) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from matplotlib->descartes) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from matplotlib->descartes) (0.11.0)
# Requirement already satisfied: six>=1.5 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->descartes) (1.16.0)
# Requirement already satisfied: mapclassify==2.3.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (2.3.0)
# Requirement already satisfied: libpysal==4.3.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (4.3.0)
# Collecting splot==1.1.3
#   Using cached splot-1.1.3-py3-none-any.whl
# Requirement already satisfied: scipy>=1.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from mapclassify==2.3.0) (1.7.1)
# Requirement already satisfied: scikit-learn in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from mapclassify==2.3.0) (1.0.1)
# Requirement already satisfied: pandas>=1.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from mapclassify==2.3.0) (1.3.4)
# Requirement already satisfied: networkx in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from mapclassify==2.3.0) (2.6.3)
# Requirement already satisfied: numpy>=1.3 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from mapclassify==2.3.0) (1.21.2)
# Requirement already satisfied: beautifulsoup4 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from libpysal==4.3.0) (4.10.0)
# Requirement already satisfied: jinja2 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from libpysal==4.3.0) (2.11.3)
# Requirement already satisfied: requests in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from libpysal==4.3.0) (2.26.0)
# Requirement already satisfied: esda in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from splot==1.1.3) (2.4.1)
# Requirement already satisfied: giddy in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from splot==1.1.3) (2.3.3)
# Requirement already satisfied: descartes in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from splot==1.1.3) (1.1.0)
# Requirement already satisfied: matplotlib in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from splot==1.1.3) (3.5.0)
# Requirement already satisfied: seaborn in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from splot==1.1.3) (0.11.2)
# Requirement already satisfied: geopandas>=0.4.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from splot==1.1.3) (0.8.2)
# Requirement already satisfied: spreg in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from splot==1.1.3) (1.2.4)
# Requirement already satisfied: shapely in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from geopandas>=0.4.0->splot==1.1.3) (1.7.1)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from geopandas>=0.4.0->splot==1.1.3) (2.6.1.post1)
# Requirement already satisfied: fiona in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from geopandas>=0.4.0->splot==1.1.3) (1.8.20)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from pandas>=1.0->mapclassify==2.3.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from pandas>=1.0->mapclassify==2.3.0) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->mapclassify==2.3.0) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from beautifulsoup4->libpysal==4.3.0) (2.3.1)
# Requirement already satisfied: click-plugins>=1.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas>=0.4.0->splot==1.1.3) (1.1.1)
# Requirement already satisfied: attrs>=17 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas>=0.4.0->splot==1.1.3) (21.2.0)
# Requirement already satisfied: munch in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas>=0.4.0->splot==1.1.3) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas>=0.4.0->splot==1.1.3) (0.7.2)
# Requirement already satisfied: click>=4.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas>=0.4.0->splot==1.1.3) (8.0.3)
# Requirement already satisfied: setuptools in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas>=0.4.0->splot==1.1.3) (58.0.4)
# Requirement already satisfied: certifi in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas>=0.4.0->splot==1.1.3) (2021.10.8)
# Requirement already satisfied: importlib-metadata in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from click>=4.0->fiona->geopandas>=0.4.0->splot==1.1.3) (4.8.2)
# Requirement already satisfied: quantecon>=0.4.7 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from giddy->splot==1.1.3) (0.5.2)
# Requirement already satisfied: sympy in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from quantecon>=0.4.7->giddy->splot==1.1.3) (1.9)
# Requirement already satisfied: numba>=0.38 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from quantecon>=0.4.7->giddy->splot==1.1.3) (0.53.1)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from numba>=0.38->quantecon>=0.4.7->giddy->splot==1.1.3) (0.36.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata->click>=4.0->fiona->geopandas>=0.4.0->splot==1.1.3) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata->click>=4.0->fiona->geopandas>=0.4.0->splot==1.1.3) (3.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from jinja2->libpysal==4.3.0) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from matplotlib->splot==1.1.3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from matplotlib->splot==1.1.3) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from matplotlib->splot==1.1.3) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from matplotlib->splot==1.1.3) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from matplotlib->splot==1.1.3) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from matplotlib->splot==1.1.3) (21.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from requests->libpysal==4.3.0) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from requests->libpysal==4.3.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from requests->libpysal==4.3.0) (3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->mapclassify==2.3.0) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->mapclassify==2.3.0) (1.1.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from sympy->quantecon>=0.4.7->giddy->splot==1.1.3) (1.2.1)
# Installing collected packages: splot
#   Attempting uninstall: splot
#     Found existing installation: splot 1.1.4
#     Uninstalling splot-1.1.4:
#       Successfully uninstalled splot-1.1.4
# Successfully installed splot-1.1.3
# Requirement already satisfied: esda in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (2.4.1)
# Requirement already satisfied: libpysal in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from esda) (4.3.0)
# Requirement already satisfied: pandas in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from esda) (1.3.4)
# Requirement already satisfied: scikit-learn in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from esda) (1.0.1)
# Requirement already satisfied: scipy>=0.11 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from esda) (1.7.1)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from scipy>=0.11->esda) (1.21.2)
# Requirement already satisfied: requests in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from libpysal->esda) (2.26.0)
# Requirement already satisfied: jinja2 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from libpysal->esda) (2.11.3)
# Requirement already satisfied: beautifulsoup4 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from libpysal->esda) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from beautifulsoup4->libpysal->esda) (2.3.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from jinja2->libpysal->esda) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from pandas->esda) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from pandas->esda) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->esda) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from requests->libpysal->esda) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from requests->libpysal->esda) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from requests->libpysal->esda) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from requests->libpysal->esda) (2021.10.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->esda) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->esda) (1.1.0)
# Requirement already satisfied: pysal in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (1.14.4.post1)
# Requirement already satisfied: numpy>=1.3 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from pysal) (1.21.2)
# Requirement already satisfied: scipy>=0.11 in /Users/whaner/opt/anaconda3/lib/python3.7/site-packages (from pysal) (1.7.1)

# %%
import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.formula.api as sm

# para gráficos
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# para a análise de dados espaciais
import geopandas as gp
import pysal as ps
import splot
import mapclassify as mc
from libpysal.weights import Queen
from libpysal import weights
from esda import Moran, Moran_Local, G_Local
from splot.esda import plot_moran, moran_scatterplot, lisa_cluster, plot_local_autocorrelation

# links com arquivos úteis
link = 'https://raw.githubusercontent.com/lincolnfrias/dados/master/'
link_p = 'https://raw.githubusercontent.com/patriciasiqueira/patriciasiqueira.github.io/master/arquivos/'
# Out:
# /Users/whaner/opt/anaconda3/lib/python3.7/site-packages/pysal/__init__.py:65: VisibleDeprecationWarning: PySAL's API will be changed on 2018-12-31. The last release made with this API is version 1.14.4. A preview of the next API version is provided in the `pysal` 2.0 prelease candidate. The API changes and a guide on how to change imports is provided at https://migrating.pysal.org
#   ), VisibleDeprecationWarning)

# %%
# ler dados de interesse
dados = pd.read_csv(link_p+'qtde-22.csv', encoding='latin1')
# quantidade produzida em toneladas em 2017

# para ler um arquivo salvo no computador
# ir primeiro em > e Files
# dados = pd.read_csv('qtde_22.csv', encoding='latin1')

# %%
# nomes das variáveis
dados.columns
# Out:
# Index(['ibge7', 'mun', 'nome_meso', 'abacate', 'abacaxi', 'alho', 'amendoim',
#        'arroz', 'aveia', 'banana', 'batata-doce', 'batata-inglesa',
#        'cafe_total', 'cafe_arab', 'cana', 'feijao', 'girassol', 'laranja',
#        'maracuja', 'milho', 'soja', 'sorgo', 'tomate', 'trigo', 'uva'],
#       dtype='object')

# %%
# número de linhas e colunas do dataframe
dados.shape
# Out:
# (853, 25)

# %%
# mostrar algumas linhas do dataframe
dados.head(3)
# Out:
#      ibge7                  mun                         nome_meso  abacate  \
# 0  3100104  Abadia dos Dourados  Triângulo Mineiro/Alto Paranaíba        0
# 1  3100203               Abaeté                   Central Mineira        0
# 2  3100302           Abre Campo                      Zona da Mata        0
#
#    abacaxi  alho  amendoim  arroz  aveia  banana  ...  feijao  girassol  \
# 0        0     0         0      2      0      47  ...      18         0
# 1      540     0         0      8      0      28  ...       0         0
# 2        0     0         0      0      0      50  ...     170         0
#
#    laranja  maracuja  milho   soja  sorgo  tomate  trigo  uva
# 0        0         0   8028  11685   1212     100      0    0
# 1        0        63   4680   1404      0       0      0    0
# 2        0         0    780      0      0       0      0    0
#
# [3 rows x 25 columns]

# %%
# renomear colunas
# 'ibge7' será 'mun' (código do município)
# 'mun' será 'município' (nome do município)

dados.rename(columns={'mun': 'municipio'}, inplace=True)  # inplace = True modifica o dataframe
dados.rename(columns={'ibge7': 'mun'}, inplace=True)

# %%
# ler shapefile
link = 'https://raw.githubusercontent.com/lincolnfrias/dados/master/mg.json'
geodf = gp.read_file(link)

# %%
geodf.head()
# Out:
#             NM_MUNICIP CD_GEOCMU  \
# 0  ABADIA DOS DOURADOS   3100104
# 1               ABAETÉ   3100203
# 2           ABRE CAMPO   3100302
# 3              ACAIACA   3100401
# 4              AÇUCENA   3100500
#
#                                             geometry
# 0  POLYGON ((-47.42967 -18.16543, -47.42307 -18.1...
# 1  POLYGON ((-45.13930 -19.21048, -45.15975 -19.1...
# 2  POLYGON ((-42.31071 -20.14279, -42.32217 -20.1...
# 3  POLYGON ((-43.02387 -20.41022, -43.03283 -20.4...
# 4  POLYGON ((-42.36208 -18.92569, -42.36636 -18.9...

# %%
# mesclar shapefile com dataframe
# usando a coluna mun
geodf.rename(columns={'CD_GEOCMU': 'mun'}, inplace=True)  # mudar nome da coluna com cód. para 'mun'
geodf['mun'] = geodf.mun.astype(int)  # transformar códigos em inteiros
mg = pd.merge(geodf, dados, on='mun', suffixes=('', '_y'))  # mesclar o dataframe e o shapefile
mg.shape
# Out:
# (853, 27)

# %%
# ver objeto resultante (dataframe + shapefile)
mg.head(3)
# Out:
#             NM_MUNICIP      mun  \
# 0  ABADIA DOS DOURADOS  3100104
# 1               ABAETÉ  3100203
# 2           ABRE CAMPO  3100302
#
#                                             geometry            municipio  \
# 0  POLYGON ((-47.42967 -18.16543, -47.42307 -18.1...  Abadia dos Dourados
# 1  POLYGON ((-45.13930 -19.21048, -45.15975 -19.1...               Abaeté
# 2  POLYGON ((-42.31071 -20.14279, -42.32217 -20.1...           Abre Campo
#
#                           nome_meso  abacate  abacaxi  alho  amendoim  arroz  \
# 0  Triângulo Mineiro/Alto Paranaíba        0        0     0         0      2
# 1                   Central Mineira        0      540     0         0      8
# 2                      Zona da Mata        0        0     0         0      0
#
#    ...  feijao  girassol  laranja  maracuja  milho   soja  sorgo  tomate  \
# 0  ...      18         0        0         0   8028  11685   1212     100
# 1  ...       0         0        0        63   4680   1404      0       0
# 2  ...     170         0        0         0    780      0      0       0
#
#    trigo  uva
# 0      0    0
# 1      0    0
# 2      0    0
#
# [3 rows x 27 columns]

# %%
mg.plot();

# %%
mg.columns
# Out:
# Index(['NM_MUNICIP', 'mun', 'geometry', 'municipio', 'nome_meso', 'abacate',
#        'abacaxi', 'alho', 'amendoim', 'arroz', 'aveia', 'banana',
#        'batata-doce', 'batata-inglesa', 'cafe_total', 'cafe_arab', 'cana',
#        'feijao', 'girassol', 'laranja', 'maracuja', 'milho', 'soja', 'sorgo',
#        'tomate', 'trigo', 'uva'],
#       dtype='object')

# %%
variavel = 'soja'

# %%
# mapa temático - simples
mg.plot(variavel);

# %% [markdown]
# Esquemas de cores: cmap (https://matplotlib.org/stable/tutorials/colors/colormaps.html)
#
# - PuBu
#
# - GnBu
#
# - Oranges
#
# - BuGn
#
# - Purples
#
# - YlOrBr

# %%
# mapa temático - com opções
# scheme='Quantiles' ou 'Equal_Interval'
# quantiles: atribui mesma quantidade de valores para cada categoria. Apesar de esconder valores extremos,
# pode se tornar mais informativa se a distribuição for assimétrica
# perceber as diferenças entre os esquemas: cmap='PuBu', por exemplo


mg.plot(column=variavel, figsize=(15, 13), scheme='quantiles', legend=True, k=4, cmap='Oranges');
# Out:
# /Users/whaner/opt/anaconda3/lib/python3.7/site-packages/mapclassify/classifiers.py:236: UserWarning: Warning: Not enough unique values in array to form k classes
#   "Warning: Not enough unique values in array to form k classes", UserWarning
# /Users/whaner/opt/anaconda3/lib/python3.7/site-packages/mapclassify/classifiers.py:238: UserWarning: Warning: setting k to 3
#   Warn("Warning: setting k to %d" % k_q, UserWarning)

# %%
# mapa temático - com opções
# scheme='equal_interval', 'fisher_jenks'
mg.plot(column=variavel, figsize=(15, 13), scheme='fisher_jenks', legend=True, k=4, cmap='Oranges');

# %%
# mapa temático - com opções
# escolher diferentes esquemas de cores
mg.plot(column=variavel, figsize=(15, 13), scheme='equal_interval', legend=True, k=4, cmap='Oranges');

# %%
# obter matriz de vizinhança no formato queen
w = Queen.from_dataframe(mg)
w.transform = 'r'

# %% [markdown]
# # I de Moran

# %% [markdown]
# Estatística mais utilizada para medir a autocorrelação espacial. Ela mede a relação do desvio padronizado de uma variável numa área com o desvio padronizado das áreas vizinhas para a mesma variável:
#
# $$I=\frac{N}{S_{0}}\frac{\displaystyle\sum_{i=1}^{n}\sum_{j=1}^{n}w_{ij}z_{i}z_{j}}{\displaystyle\sum_{i=1}^{n}z^{2}_{i}},$$
# em que:
#
# - $z_i = y_i - \bar{y}$ representa o desvio em relação à média da variável.
# - $y_i$: valor da variável em um determinado local $i$
# - $N$: número de observações
# - $S_0 = \sum\sum w_{ij}$
# - $E[I] = -1/(N - 1) \approx 0$
#
# Se o valor-$p$ referente ao teste do $I$ de Moran for significativo, podemos olhar para o valor da estatística $I$ e concluir:
#
# - $I > 0$: autocorrelação espacial positiva (*clusters* espaciais - HH, LL)
# - $I < 0$: autocorrelação espacial negativa (*outliers* espaciais - HL, LH)

# %%
# calcular I de Moran global para a variável escolhida
y = mg[variavel].values
moran = Moran(y, w)
moran.I
# Out:
# 0.4983387682998699

# %%
# valor-p
moran.p_sim
# Out:
# 0.001

# %%
# diagrama de dispersão de Moran
plot_moran(moran, zstandard=False, figsize=(10,4));

# %%
moran_loc = Moran_Local(y, w)
moran_scatterplot(moran_loc, p=0.05);

# %% [markdown]
# ### LISA
#
# - Estatística para detectar padrões locais de autocorrelação espacial: *Local Indicator of Spatial Association* (LISA), ou $I$ de Moran local
# - Permite verificar se há agrupamentos espaciais estatisticamente significativos
# - Útil quando a estatística $I$ de Moran global for significativa
#
# $$I_{i}=z_{i}\sum_{j=1}^{j}w_{ij}y_{j}$$

# %%
lisa_cluster(moran_loc, mg, p=0.05, figsize = (9,9));

# %%
plot_local_autocorrelation(moran_loc, mg, variavel);
# Out:
# /Users/whaner/opt/anaconda3/lib/python3.7/site-packages/mapclassify/classifiers.py:236: UserWarning: Warning: Not enough unique values in array to form k classes
#   "Warning: Not enough unique values in array to form k classes", UserWarning
# /Users/whaner/opt/anaconda3/lib/python3.7/site-packages/mapclassify/classifiers.py:238: UserWarning: Warning: setting k to 3
#   Warn("Warning: setting k to %d" % k_q, UserWarning)
